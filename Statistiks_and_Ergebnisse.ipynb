# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.plot(train_acc_40_wo,label='Train Accuracy 40x',linewidth=2.5)
plt.plot(train_acc_100_wo,label='Train Accuracy 100x',linewidth=2.5)
plt.plot(train_acc_200_wo,label='Train Accuracy 200x',linewidth=2.5)
plt.plot(train_acc_400_wo,label='Train Accuracy 400x',linewidth=2.5)

plt.ylim(0.38, 1.05)


plt.title('Training Accuracy vor Data Augmentation',size=20)
plt.xlabel('Epoch',size=20)
plt.ylabel('Accuracy',size=20)
plt.legend(fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()

# %%
plt.figure(figsize=(10,5))

plt.plot(train_acc_40_aug,label='Train Accuracy 40x',linewidth=2.5)
plt.plot(train_acc_100_aug,label='Train Accuracy 100x',linewidth=2.5)
plt.plot(train_acc_200_aug,label='Train Accuracy 200x',linewidth=2.5)
plt.plot(train_acc_400_aug,label='Train Accuracy 400x',linewidth=2.5)

plt.ylim(0.2, 1.05)


plt.title('Training Accuracy nach Data Augmentation',size=20)
plt.xlabel('Epoch',size=20)
plt.ylabel('Accuracy',size=20)
plt.legend(fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()

# %%
plt.figure(figsize=(10,5))
plt.plot(valid_acc_40_aug,label='Valid Accuracy 40x',linewidth=2.5)
plt.plot(valid_acc_100_aug,label='Valid Accuracy 100x',linewidth=2.5)
plt.plot(valid_acc_200_aug,label='Valid Accuracy 200x',linewidth=2.5)
plt.plot(valid_acc_400_aug,label='Train Accuracy 400x',linewidth=2.5)
plt.ylim(0.15,1)

plt.title('Validation Accuracy nach Data Augmentation',size=20)
plt.xlabel('Epoch',size=20)
plt.ylabel('Accuracy',size=20)
plt.legend(fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()

# %%
plt.figure(figsize=(10,5))
plt.plot(valid_acc_40_wo,label ='Valid Accuracy 40x',linewidth=2.5)
plt.plot(valid_acc_100_wo,label='Valid Accuracy 100x',linewidth=2.5)
plt.plot(valid_acc_200_wo,label='Valid Accuracy 200x',linewidth=2.5)
plt.plot(valid_acc_400_wo,label='Valid Accuracy 400x',linewidth=2.5)

plt.ylim(0.15,1)
plt.title('Validation Accuracy vor Data Augmentation',size=20)
plt.xlabel('Epoch',size=20)
plt.ylabel('Accuracy',size=20)
plt.legend(fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()

# %%
import glob

wo_40_train_ad = glob.glob('Breast_cancer_40/train/Adenosis/*.png')
wo_40_train_dc = glob.glob('Breast_cancer_40/train/Ductal_carcinoma/*.png')
wo_40_train_fb = glob.glob('Breast_cancer_40/train/Fibroadenoma/*.png')
wo_40_train_lc = glob.glob('Breast_cancer_40/train/Lobular_carcinoma/*.png')
wo_40_train_mc = glob.glob('Breast_cancer_40/train/Mucinous_carcinoma/*.png')
wo_40_train_pc = glob.glob('Breast_cancer_40/train/Papillary_carcinoma/*.png')
wo_40_train_pt = glob.glob('Breast_cancer_40/train/Phyllodes_tumor/*.png')
wo_40_train_ta = glob.glob('Breast_cancer_40/train/Tubular_adenoma/*.png')


print('************************')

wo_400_train_ad = glob.glob('Breast_cancer_400/train/Adenosis/*.png')
wo_400_train_dc = glob.glob('Breast_cancer_400/train/Ductal_carcinoma/*.png')
wo_400_train_fb = glob.glob('Breast_cancer_400/train/Fibroadenoma/*.png')
wo_400_train_lc = glob.glob('Breast_cancer_400/train/Lobular_carcinoma/*.png')
wo_400_train_mc = glob.glob('Breast_cancer_400/train/Mucinous_carcinoma/*.png')
wo_400_train_pc = glob.glob('Breast_cancer_400/train/Papillary_carcinoma/*.png')
wo_400_train_pt = glob.glob('Breast_cancer_400/train/Phyllodes_tumor/*.png')
wo_400_train_ta = glob.glob('Breast_cancer_400/train/Tubular_adenoma/*.png')



print('************************')
wo_100_train_ad = glob.glob('Breast_cancer_100/train/Adenosis/*.png')
wo_100_train_dc = glob.glob('Breast_cancer_100/train/Ductal_carcinoma/*.png')
wo_100_train_fb = glob.glob('Breast_cancer_100/train/Fibroadenoma/*.png')
wo_100_train_lc = glob.glob('Breast_cancer_100/train/Lobular_carcinoma/*.png')
wo_100_train_mc = glob.glob('Breast_cancer_100/train/Mucinous_carcinoma/*.png')
wo_100_train_pc = glob.glob('Breast_cancer_100/train/Papillary_carcinoma/*.png')
wo_100_train_pt = glob.glob('Breast_cancer_100/train/Phyllodes_tumor/*.png')
wo_100_train_ta = glob.glob('Breast_cancer_100/train/Tubular_adenoma/*.png')

print('************************')
wo_200_train_ad = glob.glob('Breast_cancer_200/train/Adenosis/*.png')
wo_200_train_dc = glob.glob('Breast_cancer_200/train/Ductal_carcinoma/*.png')
wo_200_train_fb = glob.glob('Breast_cancer_200/train/Fibroadenoma/*.png')
wo_200_train_lc = glob.glob('Breast_cancer_200/train/Lobular_carcinoma/*.png')
wo_200_train_mc = glob.glob('Breast_cancer_200/train/Mucinous_carcinoma/*.png')
wo_200_train_pc = glob.glob('Breast_cancer_200/train/Papillary_carcinoma/*.png')
wo_200_train_pt = glob.glob('Breast_cancer_200/train/Phyllodes_tumor/*.png')
wo_200_train_ta = glob.glob('Breast_cancer_200/train/Tubular_adenoma/*.png')
# Out:
# ************************
# ************************
# ************************

# %%
import pandas as pd

x = ['Adenosis', 'Ductal_Carcinoma', 'Fibroadenoma', 'Lobular_Carcinoma',
               'Mucinous_Carcinoma', 'Papillary_Carcinoma', 'Phyllodes_tumor', 'Tubular_adenoma']
y_40 = [len(wo_40_train_ad), len(wo_40_train_dc) ,len(wo_40_train_fb) ,len(wo_40_train_lc) ,len(wo_40_train_mc) ,
                                                len(wo_40_train_pc) ,len(wo_40_train_pt) ,len(wo_40_train_ta)]

y_100 = [len(wo_100_train_ad), len(wo_100_train_dc) ,len(wo_100_train_fb) ,len(wo_100_train_lc) ,len(wo_100_train_mc) ,
                                                len(wo_100_train_pc) ,len(wo_100_train_pt) ,len(wo_100_train_ta)]

y_200 = [len(wo_200_train_ad), len(wo_200_train_dc) ,len(wo_200_train_fb) ,len(wo_200_train_lc) ,len(wo_200_train_mc) ,
                                                len(wo_200_train_pc) ,len(wo_200_train_pt) ,len(wo_200_train_ta)]

y_400 = [len(wo_400_train_ad), len(wo_400_train_dc) ,len(wo_400_train_fb) ,len(wo_400_train_lc) ,len(wo_400_train_mc) ,
                                                len(wo_400_train_pc) ,len(wo_400_train_pt) ,len(wo_400_train_ta)]


data = {'x40': y_40,
        'x100': y_100,
        'x200': y_200,
        'x400': y_400
       }
df = pd.DataFrame(data,columns=['x40','x100','x200','x400'], index = x)

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
df.plot.barh()
plt.title('Training Bilder Verteilung')
plt.ylabel('Subklasse')
plt.xlabel('Anzahl der Bilder')
plt.show()

# %%
import glob

wo_40_valid_ad = glob.glob('Breast_cancer_40/valid/0_Adenosis_40x/*.png')
wo_40_valid_dc = glob.glob('Breast_cancer_40/valid/1_ductal_carcinoma_40x/*.png')
wo_40_valid_fb = glob.glob('Breast_cancer_40/valid/0_fibroadenoma_40x/*.png')
wo_40_valid_lc = glob.glob('Breast_cancer_40/valid/1_lobular_carcinoma_40x/*.png')
wo_40_valid_mc = glob.glob('Breast_cancer_40/valid/1_mucinous_carcinoma_40x/*.png')
wo_40_valid_pc = glob.glob('Breast_cancer_40/valid/1_papillary_carcinoma_40x/*.png')
wo_40_valid_pt = glob.glob('Breast_cancer_40/valid/0_phyllodes_tumor_40x/*.png')
wo_40_valid_ta = glob.glob('Breast_cancer_40/valid/0_tubular_adenoma_40x/*.png')



v_40 = [len(wo_40_valid_ad),len(wo_40_valid_dc),len(wo_40_valid_fb),len(wo_40_valid_lc),len(wo_40_valid_mc),
       len(wo_40_valid_pc),len(wo_40_valid_pt),len(wo_40_valid_ta)]


print('************************')
wo_100_valid_ad = glob.glob('Breast_cancer_100/valid/Adenosis/*.png')
wo_100_valid_dc = glob.glob('Breast_cancer_100/valid/Ductal_carcinoma/*.png')
wo_100_valid_fb = glob.glob('Breast_cancer_100/valid/Fibroadenoma/*.png')
wo_100_valid_lc = glob.glob('Breast_cancer_100/valid/Lobular_carcinoma/*.png')
wo_100_valid_mc = glob.glob('Breast_cancer_100/valid/Mucinous_carcinoma/*.png')
wo_100_valid_pc = glob.glob('Breast_cancer_100/valid/Papillary_carcinoma/*.png')
wo_100_valid_pt = glob.glob('Breast_cancer_100/valid/Phyllodes_tumor/*.png')
wo_100_valid_ta = glob.glob('Breast_cancer_100/valid/Tubular_adenoma/*.png')


v_100 = [len(wo_100_valid_ad),len(wo_100_valid_dc),len(wo_100_valid_fb),len(wo_100_valid_lc),len(wo_100_valid_mc),
       len(wo_100_valid_pc),len(wo_100_valid_pt),len(wo_100_valid_ta)]

print('************************')
wo_200_valid_ad = glob.glob('Breast_cancer_200/valid/Adenosis/*.png')
wo_200_valid_dc = glob.glob('Breast_cancer_200/valid/Ductal_carcinoma/*.png')
wo_200_valid_fb = glob.glob('Breast_cancer_200/valid/Fibroadenoma/*.png')
wo_200_valid_lc = glob.glob('Breast_cancer_200/valid/Lobular_carcinoma/*.png')
wo_200_valid_mc = glob.glob('Breast_cancer_200/valid/Mucinous_carcinoma/*.png')
wo_200_valid_pc = glob.glob('Breast_cancer_200/valid/Papillary_carcinoma/*.png')
wo_200_valid_pt = glob.glob('Breast_cancer_200/valid/Phyllodes_tumor/*.png')
wo_200_valid_ta = glob.glob('Breast_cancer_200/valid/Tubular_adenoma/*.png')


v_200 = [len(wo_200_valid_ad),len(wo_200_valid_dc),len(wo_200_valid_fb),len(wo_200_valid_lc),len(wo_200_valid_mc),
       len(wo_200_valid_pc),len(wo_200_valid_pt),len(wo_200_valid_ta)]

print('************************')
wo_400_valid_ad = glob.glob('Breast_cancer_400/valid/Adenosis/*.png')
wo_400_valid_dc = glob.glob('Breast_cancer_400/valid/Ductal_carcinoma/*.png')
wo_400_valid_fb = glob.glob('Breast_cancer_400/valid/Fibroadenoma/*.png')
wo_400_valid_lc = glob.glob('Breast_cancer_400/valid/Lobular_carcinoma/*.png')
wo_400_valid_mc = glob.glob('Breast_cancer_400/valid/Mucinous_carcinoma/*.png')
wo_400_valid_pc = glob.glob('Breast_cancer_400/valid/Papillary_carcinoma/*.png')
wo_400_valid_pt = glob.glob('Breast_cancer_400/valid/Phyllodes_tumor/*.png')
wo_400_valid_ta = glob.glob('Breast_cancer_400/valid/Tubular_adenoma/*.png')


v_400 = [len(wo_400_valid_ad),len(wo_400_valid_dc),len(wo_400_valid_fb),len(wo_400_valid_lc),len(wo_400_valid_mc),
       len(wo_400_valid_pc),len(wo_400_valid_pt),len(wo_400_valid_ta)]
# Out:
# ************************
# ************************
# ************************

# %%
import glob

valid = glob.glob('Breast_cancer_400/*/*/*.png')
len(valid)
# Out:
# 2115

# %%
data1 = {'x40': v_40,
        'x100': v_100,
        'x200': v_200,
        'x400': v_400
       }
df1 = pd.DataFrame(data1,columns=['x40','x100','x200','x400'], index = x)

import matplotlib.pyplot as plt
plt.figure(figsize=(25,7))
plt.style.use('fivethirtyeight')
df1.plot.barh()
plt.title('Validation Bilder Verteilung')
plt.ylabel('Subklasse')
plt.xlabel('Anzahl der Bilder')
plt.show()

# %%
import glob

wo_40_test_ad = glob.glob('Breast_cancer_40/test/0_Adenosis_40x/*.png')
wo_40_test_dc = glob.glob('Breast_cancer_40/test/1_ductal_carcinoma_40x/*.png')
wo_40_test_fb = glob.glob('Breast_cancer_40/test/0_fibroadenoma_40x/*.png')
wo_40_test_lc = glob.glob('Breast_cancer_40/test/1_lobular_carcinoma_40x/*.png')
wo_40_test_mc = glob.glob('Breast_cancer_40/test/1_mucinous_carcinoma_40x/*.png')
wo_40_test_pc = glob.glob('Breast_cancer_40/test/1_papillary_carcinoma_40x/*.png')
wo_40_test_pt = glob.glob('Breast_cancer_40/test/0_phyllodes_tumor_40x/*.png')
wo_40_test_ta = glob.glob('Breast_cancer_40/test/0_tubular_adenoma_40x/*.png')



t_40 = [len(wo_40_test_ad),len(wo_40_test_dc),len(wo_40_test_fb),len(wo_40_test_lc),len(wo_40_test_mc),
       len(wo_40_test_pc),len(wo_40_test_pt),len(wo_40_test_ta)]


print('************************')
wo_100_test_ad = glob.glob('Breast_cancer_100/test/Adenosis/*.png')
wo_100_test_dc = glob.glob('Breast_cancer_100/test/Ductal_carcinoma/*.png')
wo_100_test_fb = glob.glob('Breast_cancer_100/test/Fibroadenoma/*.png')
wo_100_test_lc = glob.glob('Breast_cancer_100/test/Lobular_carcinoma/*.png')
wo_100_test_mc = glob.glob('Breast_cancer_100/test/Mucinous_carcinoma/*.png')
wo_100_test_pc = glob.glob('Breast_cancer_100/test/Papillary_carcinoma/*.png')
wo_100_test_pt = glob.glob('Breast_cancer_100/test/Phyllodes_tumor/*.png')
wo_100_test_ta = glob.glob('Breast_cancer_100/test/Tubular_adenoma/*.png')


t_100 = [len(wo_100_test_ad),len(wo_100_test_dc),len(wo_100_test_fb),len(wo_100_test_lc),len(wo_100_test_mc),
       len(wo_100_test_pc),len(wo_100_test_pt),len(wo_100_test_ta)]

print('************************')
wo_200_test_ad = glob.glob('Breast_cancer_200/test/0_Adenosis_200x/*.png')
wo_200_test_dc = glob.glob('Breast_cancer_200/test/1_ductal_carcinoma_200x/*.png')
wo_200_test_fb = glob.glob('Breast_cancer_200/test/0_fibroadenoma_200x/*.png')
wo_200_test_lc = glob.glob('Breast_cancer_200/test/1_lobular_carcinoma_200x/*.png')
wo_200_test_mc = glob.glob('Breast_cancer_200/test/1_mucinous_carcinoma_200x/*.png')
wo_200_test_pc = glob.glob('Breast_cancer_200/test/1_papillary_carcinoma-200x/*.png')
wo_200_test_pt = glob.glob('Breast_cancer_200/test/0_phyllodes_tumor_200x/*.png')
wo_200_test_ta = glob.glob('Breast_cancer_200/test/0_tubular_adenoma_200x/*.png')


t_200 = [len(wo_200_test_ad),len(wo_200_test_dc),len(wo_200_test_fb),len(wo_200_test_lc),len(wo_200_test_mc),
       len(wo_200_test_pc),len(wo_200_test_pt),len(wo_200_test_ta)]

print('************************')
wo_400_test_ad = glob.glob('Breast_cancer_400/test/Adenosis/*.png')
wo_400_test_dc = glob.glob('Breast_cancer_400/test/Ductal_carcinoma/*.png')
wo_400_test_fb = glob.glob('Breast_cancer_400/test/Fibroadenoma/*.png')
wo_400_test_lc = glob.glob('Breast_cancer_400/test/Lobular_carcinoma/*.png')
wo_400_test_mc = glob.glob('Breast_cancer_400/test/Mucinous_carcinoma/*.png')
wo_400_test_pc = glob.glob('Breast_cancer_400/test/Papillary_carcinoma/*.png')
wo_400_test_pt = glob.glob('Breast_cancer_400/test/Phyllodes_tumor/*.png')
wo_400_test_ta = glob.glob('Breast_cancer_400/test/Tubular_adenoma/*.png')


t_400 = [len(wo_400_test_ad),len(wo_400_test_dc),len(wo_400_test_fb),len(wo_400_test_lc),len(wo_400_test_mc),
       len(wo_400_test_pc),len(wo_400_test_pt),len(wo_400_test_ta)]
# Out:
# ************************
# ************************
# ************************

# %%
import torch 
print(torch.__version__)
# Out:
# 1.10.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-7fcf4273bd03> in <module>
# ----> 1 nvcc --version
#
# NameError: name 'nvcc' is not defined

# %%
conda install pytorch-cpu torchvision-cpu -c pytorch
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - pytorch-cpu
#
# Current channels:
#
#   - https://conda.anaconda.org/pytorch/osx-64
#   - https://conda.anaconda.org/pytorch/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
data2 = {'x40': t_40,
        'x100': t_100,
        'x200': t_200,
        'x400': t_400
       }
df2 = pd.DataFrame(data2,columns=['x40','x100','x200','x400'], index = x)

import matplotlib.pyplot as plt
plt.figure(figsize=(25,7))
plt.style.use('fivethirtyeight')
df2.plot.barh()
plt.title('Testing Bilder Verteilung')
plt.ylabel('Subklasse')
plt.xlabel('Anzahl der Bilder')
plt.show()

# %%
wo_40_klassen =  [65.6 , 93.1 , 84.6 , 74.2 , 73.2 , 62.1 , 61.9 ,66.7]
wo_100_klassen = [68.2 , 92.8 , 80   , 67.6 , 75   , 62.1 , 65.8 ,70  ]
wo_200_klassen = [66.7 , 95.5 , 82.7 , 76.8 , 76.9 , 68.9 , 63.2 ,67.9]
wo_400_klassen = [69.2 , 93.4 , 87.2 , 77.9 , 75.7 , 64.3 , 66.6 ,71.9]


data3 = {'x40': wo_40_klassen,
         'x100' : wo_100_klassen,
         'x200' : wo_200_klassen,
         'x400' : wo_400_klassen
         
         }
df3 = pd.DataFrame(data3,columns=['x40','x100','x200','x400'], index = x)

import matplotlib.pyplot as plt
plt.figure(figsize=(25,7))
plt.style.use('default')
df3.plot.barh()
plt.title('Testing Accurary vor Data Augmentation für jede Subklasse')
plt.ylabel('Subklasse')
plt.xlabel('Accuracy')
plt.grid(True)
plt.show()

# %%
aug_40_klassen =  [91   , 82.6 , 88.4 , 81.4 , 94.2 , 90.7 , 90.7 ,79.7]
aug_100_klassen = [85.7 , 83.8 , 84.8 , 79   , 84.8 , 85.7 , 88.6 ,86.7]
aug_200_klassen = [92.1 , 82.5 , 89.7 , 84.8 , 87.9 , 80.9 , 82.2 ,87.9]
aug_400_klassen = [84.7 , 90.3 , 84.5 , 90.9 , 95.7 , 89.8 , 90.8 ,90.9]


data4 = {'x40': aug_40_klassen,
         'x100' : aug_100_klassen,
         'x200' : aug_200_klassen,
         'x400' : aug_400_klassen
         
         }
df4 = pd.DataFrame(data4,columns=['x40','x100','x200','x400'], index = x)


plt.style.use('default')
df4.plot.barh()
plt.title('Testing Accurary nach Data Augmentation für jede Subklasse')
plt.ylabel('Subklasse')
plt.xlabel('Accuracy')
plt.grid(True)
plt.show()
