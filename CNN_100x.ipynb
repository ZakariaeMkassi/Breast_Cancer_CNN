# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models 
from torchvision.utils import make_grid#
import torchvision
import os
import random
from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
def build_datasets():

    transform = transforms.Compose([
        transforms.Resize((256,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    
    trainset = torchvision.datasets.ImageFolder(root='Breast_cancer_100/train', transform=transform)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)
    validset = torchvision.datasets.ImageFolder(root='Breast_cancer_100/valid', transform=transform)
    validloader = torch.utils.data.DataLoader(validset, batch_size=32,
                                         shuffle=True, num_workers=2)
    testset = torchvision.datasets.ImageFolder(root='Breast_cancer_100/test', transform=transform)
    testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

    return trainloader,validloader, testloader

classes = ('Adenosis', 'Ductal_Carcinoma', 'Fibroadenoma', 'Lobular_Carcinoma',
               'Mucinous_Carcinoma', 'Papillary_Carcinoma', 'Phyllodes_tumor', 'Tubular_adenoma')

# %%
trainloader,validloader ,testloader = build_datasets()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-1539f958aadf> in <module>
# ----> 1 trainloader,validloader ,testloader = build_datasets()
#
# <ipython-input-8-394662aa9df6> in build_datasets()
#       7     ])
#       8
# ----> 9     trainset = torchvision.datasets.ImageFolder(root='Breast_cancer_100/train', transform=transform)
#      10     trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
#      11                                           shuffle=True, num_workers=2)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     308             is_valid_file: Optional[Callable[[str], bool]] = None,
#     309     ):
# --> 310         super(ImageFolder, self).__init__(root, loader, IMG_EXTENSIONS if is_valid_file is None else None,
#     311                                           transform=transform,
#     312                                           target_transform=target_transform,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     144                                             target_transform=target_transform)
#     145         classes, class_to_idx = self.find_classes(self.root)
# --> 146         samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147
#     148         self.loader = loader
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     190                 "The class_to_idx parameter cannot be None."
#     191             )
# --> 192         return make_dataset(directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file)
#     193
#     194     def find_classes(self, directory: str) -> Tuple[List[str], Dict[str, int]]:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     100         if extensions is not None:
#     101             msg += f"Supported extensions are: {', '.join(extensions)}"
# --> 102         raise FileNotFoundError(msg)
#     103
#     104     return instances
#
# FileNotFoundError: Found no valid file for the classes .ipynb_checkpoints. Supported extensions are: .jpg, .jpeg, .png, .ppm, .bmp, .pgm, .tif, .tiff, .webp

# %%
import torch.nn as nn
import torch.nn.functional as F
# define the CNN architecture

class CNN(nn.Module):
    def __init__(self, num_classes: int = 8, dropout: float = 0.5) -> None:
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(96, 256, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(256, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.maxpool = nn.MaxPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(p=dropout),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=dropout),
            nn.Linear(4096, 1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.features(x)
        x = self.maxpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

net = CNN()
net
# Out:
# CNN(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (maxpool): MaxPool2d(kernel_size=(6, 6), stride=(6, 6), padding=0, dilation=1, ceil_mode=False)
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=1024, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=1024, out_features=8, bias=True)
#   )
# )

# %%
import torch.optim as optim


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

def train(model, iterator, optimizer, criterion, device):
    epoch_loss = 0
    epoch_acc = 0
    model.train()
    for (x, y) in iterator:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        y_pred = model(x)

        loss = criterion(y_pred, y)

        acc = calculate_accuracy(y_pred, y)

        loss.backward()

        optimizer.step()

        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

def valid(model,iterator):
    epoch_loss = 0
    epoch_acc = 0

    model.eval()

    for (x, y) in iterator:
        x = x.to(device)
        y = y.to(device)
        y_pred = model(x)
        loss = criterion(y_pred, y)
        acc = calculate_accuracy(y_pred, y)

        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)


def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import seaborn as sn
import torch.nn as nn
import torch.nn.functional as F
import time

train_l = []
train_a = []
valid_l = []
valid_a = []

if __name__ == '__main__':

    for epoch in range(100):
        start_time = time.monotonic()
        train_loss, train_acc = train(net, trainloader, optimizer, criterion, device)
        valid_loss, valid_acc = valid(net, validloader)
        
        train_l.append(train_loss)
        train_a.append(train_acc)
        valid_l.append(valid_loss)
        valid_a.append(valid_acc)
        
        end_time = time.monotonic()
        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        print(f'Epoch: {epoch + 1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
        print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc * 100:.2f}%')
        print(f'\tValid Loss: {valid_loss:.3f} | Valid Acc: {valid_acc * 100:.2f}%')
    print('Finished Training')

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network test images: %d %%' % (
            100 * correct / total))
# Out:
# Epoch: 01 | Epoch Time: 1m 37s
# 	Train Loss: 1.724 | Train Acc: 42.05%
# 	Valid Loss: 1.866 | Valid Acc: 43.54%
# Epoch: 02 | Epoch Time: 1m 38s
# 	Train Loss: 1.624 | Train Acc: 43.46%
# 	Valid Loss: 1.926 | Valid Acc: 43.61%
# Epoch: 03 | Epoch Time: 1m 37s
# 	Train Loss: 1.577 | Train Acc: 45.58%
# 	Valid Loss: 1.750 | Valid Acc: 44.64%
# Epoch: 04 | Epoch Time: 1m 37s
# 	Train Loss: 1.523 | Train Acc: 48.53%
# 	Valid Loss: 1.684 | Valid Acc: 47.22%
# Epoch: 05 | Epoch Time: 1m 37s
# 	Train Loss: 1.472 | Train Acc: 48.85%
# 	Valid Loss: 1.588 | Valid Acc: 45.74%
# Epoch: 06 | Epoch Time: 1m 37s
# 	Train Loss: 1.413 | Train Acc: 50.00%
# 	Valid Loss: 1.747 | Valid Acc: 47.18%
# Epoch: 07 | Epoch Time: 1m 37s
# 	Train Loss: 1.403 | Train Acc: 51.03%
# 	Valid Loss: 1.448 | Valid Acc: 50.89%
# Epoch: 08 | Epoch Time: 1m 37s
# 	Train Loss: 1.299 | Train Acc: 53.33%
# 	Valid Loss: 1.392 | Valid Acc: 50.82%
# Epoch: 09 | Epoch Time: 1m 37s
# 	Train Loss: 1.212 | Train Acc: 55.64%
# 	Valid Loss: 1.366 | Valid Acc: 54.16%
# Epoch: 10 | Epoch Time: 1m 37s
# 	Train Loss: 1.199 | Train Acc: 56.03%
# 	Valid Loss: 1.487 | Valid Acc: 54.50%
# Epoch: 11 | Epoch Time: 1m 37s
# 	Train Loss: 1.159 | Train Acc: 56.92%
# 	Valid Loss: 1.419 | Valid Acc: 55.43%
# Epoch: 12 | Epoch Time: 1m 37s
# 	Train Loss: 1.025 | Train Acc: 61.15%
# 	Valid Loss: 1.311 | Valid Acc: 58.86%
# Epoch: 13 | Epoch Time: 1m 37s
# 	Train Loss: 0.925 | Train Acc: 64.94%
# 	Valid Loss: 1.342 | Valid Acc: 65.28%
# Epoch: 14 | Epoch Time: 1m 37s
# 	Train Loss: 0.890 | Train Acc: 65.96%
# 	Valid Loss: 1.314 | Valid Acc: 69.47%
# Epoch: 15 | Epoch Time: 1m 37s
# 	Train Loss: 0.675 | Train Acc: 74.94%
# 	Valid Loss: 1.175 | Valid Acc: 77.37%
# Epoch: 16 | Epoch Time: 1m 37s
# 	Train Loss: 0.520 | Train Acc: 80.38%
# 	Valid Loss: 1.329 | Valid Acc: 78.78%
# Epoch: 17 | Epoch Time: 1m 37s
# 	Train Loss: 0.532 | Train Acc: 81.28%
# 	Valid Loss: 1.286 | Valid Acc: 78.57%
# Epoch: 18 | Epoch Time: 1m 37s
# 	Train Loss: 0.352 | Train Acc: 88.46%
# 	Valid Loss: 1.092 | Valid Acc: 76.55%
# Epoch: 19 | Epoch Time: 1m 37s
# 	Train Loss: 0.268 | Train Acc: 91.15%
# 	Valid Loss: 1.256 | Valid Acc: 78.81%
# Epoch: 20 | Epoch Time: 1m 37s
# 	Train Loss: 0.206 | Train Acc: 93.14%
# 	Valid Loss: 1.395 | Valid Acc: 83.10%
# Epoch: 21 | Epoch Time: 1m 37s
# 	Train Loss: 0.203 | Train Acc: 92.82%
# 	Valid Loss: 1.262 | Valid Acc: 81.70%
# Epoch: 22 | Epoch Time: 1m 38s
# 	Train Loss: 0.146 | Train Acc: 95.45%
# 	Valid Loss: 1.626 | Valid Acc: 83.62%
# Epoch: 23 | Epoch Time: 1m 37s
# 	Train Loss: 0.203 | Train Acc: 93.59%
# 	Valid Loss: 1.402 | Valid Acc: 82.66%
# Epoch: 24 | Epoch Time: 1m 37s
# 	Train Loss: 0.130 | Train Acc: 95.38%
# 	Valid Loss: 1.520 | Valid Acc: 82.69%
# Epoch: 25 | Epoch Time: 1m 37s
# 	Train Loss: 0.110 | Train Acc: 95.96%
# 	Valid Loss: 1.287 | Valid Acc: 81.22%
# Epoch: 26 | Epoch Time: 1m 37s
# 	Train Loss: 0.101 | Train Acc: 96.15%
# 	Valid Loss: 1.655 | Valid Acc: 82.18%
# Epoch: 27 | Epoch Time: 1m 37s
# 	Train Loss: 0.085 | Train Acc: 96.73%
# 	Valid Loss: 2.001 | Valid Acc: 81.01%
# Epoch: 28 | Epoch Time: 1m 37s
# 	Train Loss: 0.099 | Train Acc: 96.28%
# 	Valid Loss: 1.396 | Valid Acc: 82.66%
# Epoch: 29 | Epoch Time: 1m 37s
# 	Train Loss: 0.080 | Train Acc: 96.41%
# 	Valid Loss: 1.795 | Valid Acc: 81.94%
# Epoch: 30 | Epoch Time: 1m 37s
# 	Train Loss: 0.064 | Train Acc: 97.12%
# 	Valid Loss: 1.707 | Valid Acc: 82.66%
# Epoch: 31 | Epoch Time: 1m 37s
# 	Train Loss: 0.055 | Train Acc: 97.44%
# 	Valid Loss: 1.873 | Valid Acc: 82.38%
# Epoch: 32 | Epoch Time: 1m 37s
# 	Train Loss: 0.059 | Train Acc: 96.99%
# 	Valid Loss: 2.179 | Valid Acc: 82.93%
# Epoch: 33 | Epoch Time: 1m 20s
# 	Train Loss: 0.047 | Train Acc: 97.63%
# 	Valid Loss: 1.930 | Valid Acc: 82.18%
# Epoch: 34 | Epoch Time: 1m 14s
# 	Train Loss: 0.112 | Train Acc: 95.71%
# 	Valid Loss: 1.159 | Valid Acc: 81.63%
# Epoch: 35 | Epoch Time: 1m 14s
# 	Train Loss: 0.061 | Train Acc: 97.37%
# 	Valid Loss: 1.903 | Valid Acc: 82.93%
# Epoch: 36 | Epoch Time: 1m 11s
# 	Train Loss: 0.048 | Train Acc: 97.76%
# 	Valid Loss: 1.877 | Valid Acc: 82.93%
# Epoch: 37 | Epoch Time: 1m 12s
# 	Train Loss: 0.046 | Train Acc: 97.37%
# 	Valid Loss: 1.888 | Valid Acc: 82.62%
# Epoch: 38 | Epoch Time: 1m 12s
# 	Train Loss: 0.054 | Train Acc: 97.56%
# 	Valid Loss: 1.893 | Valid Acc: 82.14%
# Epoch: 39 | Epoch Time: 1m 12s
# 	Train Loss: 0.047 | Train Acc: 97.50%
# 	Valid Loss: 1.944 | Valid Acc: 82.62%
# Epoch: 40 | Epoch Time: 1m 12s
# 	Train Loss: 0.047 | Train Acc: 97.31%
# 	Valid Loss: 2.201 | Valid Acc: 82.62%
# Epoch: 41 | Epoch Time: 1m 12s
# 	Train Loss: 0.071 | Train Acc: 97.24%
# 	Valid Loss: 2.035 | Valid Acc: 82.66%
# Epoch: 42 | Epoch Time: 1m 12s
# 	Train Loss: 0.088 | Train Acc: 96.47%
# 	Valid Loss: 1.600 | Valid Acc: 78.61%
# Epoch: 43 | Epoch Time: 1m 12s
# 	Train Loss: 0.085 | Train Acc: 96.79%
# 	Valid Loss: 1.569 | Valid Acc: 81.46%
# Epoch: 44 | Epoch Time: 1m 12s
# 	Train Loss: 0.048 | Train Acc: 97.24%
# 	Valid Loss: 1.960 | Valid Acc: 82.90%
# Epoch: 45 | Epoch Time: 1m 12s
# 	Train Loss: 0.043 | Train Acc: 97.44%
# 	Valid Loss: 1.937 | Valid Acc: 82.90%
# Epoch: 46 | Epoch Time: 1m 13s
# 	Train Loss: 0.046 | Train Acc: 97.63%
# 	Valid Loss: 2.264 | Valid Acc: 83.17%
# Epoch: 47 | Epoch Time: 1m 12s
# 	Train Loss: 0.040 | Train Acc: 97.82%
# 	Valid Loss: 2.028 | Valid Acc: 83.38%
# Epoch: 48 | Epoch Time: 1m 12s
# 	Train Loss: 0.045 | Train Acc: 97.12%
# 	Valid Loss: 1.770 | Valid Acc: 82.86%
# Epoch: 49 | Epoch Time: 1m 12s
# 	Train Loss: 0.043 | Train Acc: 97.63%
# 	Valid Loss: 1.995 | Valid Acc: 82.69%
# Epoch: 50 | Epoch Time: 1m 13s
# 	Train Loss: 0.035 | Train Acc: 98.08%
# 	Valid Loss: 2.109 | Valid Acc: 83.62%
# Epoch: 51 | Epoch Time: 1m 12s
# 	Train Loss: 0.038 | Train Acc: 97.76%
# 	Valid Loss: 2.033 | Valid Acc: 83.17%
# Epoch: 52 | Epoch Time: 1m 12s
# 	Train Loss: 0.037 | Train Acc: 97.56%
# 	Valid Loss: 2.358 | Valid Acc: 83.10%
# Epoch: 53 | Epoch Time: 1m 12s
# 	Train Loss: 0.039 | Train Acc: 97.56%
# 	Valid Loss: 2.164 | Valid Acc: 82.45%
# Epoch: 54 | Epoch Time: 1m 12s
# 	Train Loss: 0.036 | Train Acc: 97.50%
# 	Valid Loss: 2.372 | Valid Acc: 82.69%
# Epoch: 55 | Epoch Time: 1m 12s
# 	Train Loss: 0.036 | Train Acc: 97.69%
# 	Valid Loss: 2.299 | Valid Acc: 83.38%
# Epoch: 56 | Epoch Time: 1m 46s
# 	Train Loss: 0.038 | Train Acc: 97.82%
# 	Valid Loss: 2.598 | Valid Acc: 81.66%
# Epoch: 57 | Epoch Time: 1m 57s
# 	Train Loss: 0.039 | Train Acc: 97.18%
# 	Valid Loss: 2.803 | Valid Acc: 82.93%
# Epoch: 58 | Epoch Time: 1m 51s
# 	Train Loss: 0.051 | Train Acc: 97.05%
# 	Valid Loss: 1.976 | Valid Acc: 81.49%
# Epoch: 59 | Epoch Time: 1m 53s
# 	Train Loss: 0.044 | Train Acc: 97.24%
# 	Valid Loss: 1.976 | Valid Acc: 82.18%
# Epoch: 60 | Epoch Time: 1m 52s
# 	Train Loss: 0.042 | Train Acc: 97.05%
# 	Valid Loss: 2.232 | Valid Acc: 81.90%
# Epoch: 61 | Epoch Time: 1m 53s
# 	Train Loss: 0.040 | Train Acc: 97.63%
# 	Valid Loss: 2.285 | Valid Acc: 82.62%
# Epoch: 62 | Epoch Time: 1m 54s
# 	Train Loss: 0.037 | Train Acc: 97.50%
# 	Valid Loss: 2.570 | Valid Acc: 82.59%
# Epoch: 63 | Epoch Time: 2m 5s
# 	Train Loss: 0.035 | Train Acc: 97.82%
# 	Valid Loss: 2.435 | Valid Acc: 82.42%
# Epoch: 64 | Epoch Time: 2m 3s
# 	Train Loss: 0.036 | Train Acc: 97.88%
# 	Valid Loss: 2.565 | Valid Acc: 82.62%
# Epoch: 65 | Epoch Time: 1m 58s
# 	Train Loss: 0.039 | Train Acc: 97.63%
# 	Valid Loss: 2.595 | Valid Acc: 82.62%
# Epoch: 66 | Epoch Time: 1m 56s
# 	Train Loss: 0.035 | Train Acc: 97.82%
# 	Valid Loss: 2.595 | Valid Acc: 82.90%
# Epoch: 67 | Epoch Time: 1m 56s
# 	Train Loss: 0.040 | Train Acc: 97.18%
# 	Valid Loss: 2.537 | Valid Acc: 82.38%
# Epoch: 68 | Epoch Time: 1m 55s
# 	Train Loss: 0.037 | Train Acc: 97.63%
# 	Valid Loss: 2.418 | Valid Acc: 81.73%
# Epoch: 69 | Epoch Time: 1m 55s
# 	Train Loss: 0.037 | Train Acc: 97.63%
# 	Valid Loss: 2.595 | Valid Acc: 81.46%
# Epoch: 70 | Epoch Time: 1m 54s
# 	Train Loss: 0.035 | Train Acc: 98.01%
# 	Valid Loss: 2.743 | Valid Acc: 83.14%
# Epoch: 71 | Epoch Time: 1m 56s
# 	Train Loss: 0.034 | Train Acc: 97.56%
# 	Valid Loss: 2.605 | Valid Acc: 82.21%
# Epoch: 72 | Epoch Time: 1m 55s
# 	Train Loss: 0.039 | Train Acc: 97.56%
# 	Valid Loss: 2.597 | Valid Acc: 81.73%
# Epoch: 73 | Epoch Time: 1m 54s
# 	Train Loss: 0.033 | Train Acc: 98.01%
# 	Valid Loss: 2.779 | Valid Acc: 83.38%
# Epoch: 74 | Epoch Time: 1m 52s
# 	Train Loss: 0.037 | Train Acc: 97.63%
# 	Valid Loss: 2.654 | Valid Acc: 82.21%
# Epoch: 75 | Epoch Time: 1m 56s
# 	Train Loss: 0.032 | Train Acc: 98.21%
# 	Valid Loss: 2.783 | Valid Acc: 82.90%
# Epoch: 76 | Epoch Time: 1m 55s
# 	Train Loss: 0.038 | Train Acc: 97.44%
# 	Valid Loss: 2.789 | Valid Acc: 82.86%
# Epoch: 77 | Epoch Time: 1m 53s
# 	Train Loss: 0.032 | Train Acc: 98.08%
# 	Valid Loss: 2.809 | Valid Acc: 82.21%
# Epoch: 78 | Epoch Time: 1m 57s
# 	Train Loss: 0.031 | Train Acc: 98.40%
# 	Valid Loss: 2.830 | Valid Acc: 82.90%
# Epoch: 79 | Epoch Time: 1m 54s
# 	Train Loss: 0.036 | Train Acc: 97.37%
# 	Valid Loss: 2.913 | Valid Acc: 82.45%
# Epoch: 80 | Epoch Time: 1m 53s
# 	Train Loss: 0.039 | Train Acc: 97.44%
# 	Valid Loss: 2.451 | Valid Acc: 83.62%
# Epoch: 81 | Epoch Time: 1m 55s
# 	Train Loss: 0.052 | Train Acc: 97.44%
# 	Valid Loss: 3.007 | Valid Acc: 82.42%
# Epoch: 82 | Epoch Time: 2m 15s
# 	Train Loss: 0.075 | Train Acc: 96.28%
# 	Valid Loss: 1.936 | Valid Acc: 80.98%
# Epoch: 83 | Epoch Time: 2m 20s
# 	Train Loss: 0.043 | Train Acc: 97.56%
# 	Valid Loss: 2.151 | Valid Acc: 81.94%
# Epoch: 84 | Epoch Time: 2m 23s
# 	Train Loss: 0.035 | Train Acc: 98.08%
# 	Valid Loss: 2.674 | Valid Acc: 82.21%
# Epoch: 85 | Epoch Time: 2m 31s
# 	Train Loss: 0.034 | Train Acc: 98.01%
# 	Valid Loss: 2.546 | Valid Acc: 82.42%
# Epoch: 86 | Epoch Time: 2m 36s
# 	Train Loss: 0.037 | Train Acc: 97.24%
# 	Valid Loss: 2.427 | Valid Acc: 82.38%
# Epoch: 87 | Epoch Time: 2m 32s
# 	Train Loss: 0.043 | Train Acc: 97.44%
# 	Valid Loss: 2.472 | Valid Acc: 82.45%
# Epoch: 88 | Epoch Time: 2m 30s
# 	Train Loss: 0.040 | Train Acc: 97.44%
# 	Valid Loss: 2.613 | Valid Acc: 82.42%
# Epoch: 89 | Epoch Time: 2m 27s
# 	Train Loss: 0.034 | Train Acc: 97.56%
# 	Valid Loss: 2.701 | Valid Acc: 82.18%
# Epoch: 90 | Epoch Time: 2m 29s
# 	Train Loss: 0.036 | Train Acc: 97.95%
# 	Valid Loss: 2.661 | Valid Acc: 81.46%
# Epoch: 91 | Epoch Time: 2m 22s
# 	Train Loss: 0.033 | Train Acc: 97.82%
# 	Valid Loss: 2.922 | Valid Acc: 81.22%
# Epoch: 92 | Epoch Time: 2m 23s
# 	Train Loss: 0.032 | Train Acc: 97.95%
# 	Valid Loss: 2.705 | Valid Acc: 82.62%
# Epoch: 93 | Epoch Time: 2m 21s
# 	Train Loss: 0.037 | Train Acc: 97.50%
# 	Valid Loss: 2.798 | Valid Acc: 82.21%
# Epoch: 94 | Epoch Time: 2m 18s
# 	Train Loss: 0.118 | Train Acc: 95.96%
# 	Valid Loss: 1.718 | Valid Acc: 81.25%
# Epoch: 95 | Epoch Time: 2m 21s
# 	Train Loss: 0.042 | Train Acc: 97.88%
# 	Valid Loss: 2.044 | Valid Acc: 82.18%
# Epoch: 96 | Epoch Time: 2m 19s
# 	Train Loss: 0.039 | Train Acc: 97.56%
# 	Valid Loss: 2.267 | Valid Acc: 81.01%
# Epoch: 97 | Epoch Time: 2m 20s
# 	Train Loss: 0.044 | Train Acc: 97.50%
# 	Valid Loss: 2.431 | Valid Acc: 80.46%
# Epoch: 98 | Epoch Time: 2m 19s
# 	Train Loss: 0.050 | Train Acc: 97.24%
# 	Valid Loss: 2.457 | Valid Acc: 81.73%
# Epoch: 99 | Epoch Time: 2m 22s
# 	Train Loss: 0.035 | Train Acc: 97.82%
# 	Valid Loss: 2.504 | Valid Acc: 81.70%
# Epoch: 100 | Epoch Time: 2m 22s
# 	Train Loss: 0.037 | Train Acc: 97.69%
# 	Valid Loss: 2.449 | Valid Acc: 81.70%
# Finished Training
# Accuracy of the network test images: 81 %

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print("Accuracy for class {:5s} is: {:.1f} %".format(classname,
                                                   accuracy))
# Out:
# Accuracy for class Adenosis is: 68.2 %
# Accuracy for class Ductal_Carcinoma is: 92.8 %
# Accuracy for class Fibroadenoma is: 75.0 %
# Accuracy for class Lobular_Carcinoma is: 67.6 %
# Accuracy for class Mucinous_Carcinoma is: 75.0 %
# Accuracy for class Papillary_Carcinoma is: 82.1 %
# Accuracy for class Phyllodes_tumor is: 70.8 %
# Accuracy for class Tubular_adenoma is: 70.0 %

# %%
plt.figure(figsize=(12,6))
plt.plot(valid_l,label='Train Loss',linewidth=2)
plt.plot(train_l,label='Valid Loss',linewidth=2)
plt.xlabel('Epoch',size=20)
plt.ylabel('Loss',size=20)
plt.legend(fontsize = 20)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee5601c3263d> in <module>
#       1 plt.figure(figsize=(12,6))
# ----> 2 plt.plot(valid_l,label='Train Loss',linewidth=2)
#       3 plt.plot(train_l,label='Valid Loss',linewidth=2)
#       4 plt.xlabel('Epoch',size=20)
#       5 plt.ylabel('Loss',size=20)
#
# NameError: name 'valid_l' is not defined

# %%
plt.figure(figsize=(12,6))
plt.plot(valid_a,label='Train Accuracy',linewidth=2)
plt.plot(train_a,label='Valid Accuracy',linewidth=2)
plt.xlabel('Epoch',size=20)
plt.ylabel('Loss',size=20)
plt.legend(fontsize = 20)
plt.grid()

# %%
classes = ('Adenosis', 'Ductal_Carcinoma', 'Fibroadenoma', 'Lobular_Carcinoma',
               'Mucinous_Carcinoma', 'Papillary_Carcinoma', 'Phyllodes_tumor', 'Tubular_adenoma')

# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print("Accuracy for class {:5s} is: {:.1f} %".format(classname,
                                                   accuracy))
# Out:
# Accuracy for class Adenosis is: 77.3 %
# Accuracy for class Ductal_Carcinoma is: 96.7 %
# Accuracy for class Fibroadenoma is: 76.9 %
# Accuracy for class Lobular_Carcinoma is: 44.1 %
# Accuracy for class Mucinous_Carcinoma is: 50.0 %
# Accuracy for class Papillary_Carcinoma is: 46.4 %
# Accuracy for class Phyllodes_tumor is: 54.2 %
# Accuracy for class Tubular_adenoma is: 80.0 %

# %%
import sklearn

def test_label_predictions(model, device, test_loader):
    model.eval()
    actuals = []
    predictions = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            prediction = output.argmax(dim=1, keepdim=True)
            actuals.extend(target.view_as(prediction))
            predictions.extend(prediction)
    return [i.item() for i in actuals], [i.item() for i in predictions]

actuals, predictions = test_label_predictions(net, device, testloader)
print('Confusion matrix:')
print(sklearn.metrics.confusion_matrix(actuals, predictions))
print('F1 score: %f' % sklearn.metrics.f1_score(actuals, predictions, average='micro'))
print('Accuracy score: %f' % sklearn.metrics.accuracy_score(actuals, predictions))
# Out:
# Confusion matrix:
# [[ 15   0   4   0   1   2   0   0]
#  [  2 168   2   1   6   1   1   0]
#  [  1   8  39   2   1   0   0   1]
#  [  0  10   1  23   0   0   0   0]
#  [  0   5   3   1  33   1   0   1]
#  [  0   3   1   0   1  23   0   0]
#  [  2   0   3   0   2   0  17   0]
#  [  0   4   3   0   2   0   0  21]]
# F1 score: 0.816867
# Accuracy score: 0.816867

# %%
a = [[ 15,   0  , 4   ,0  , 1  , 2  , 0 ,  0],
     [  2 ,168  , 2  , 1  , 6 ,  1  , 1  , 0],
     [  1 ,  8  ,39  , 2  , 1  , 0   ,0   ,1],
     [  0  ,10 ,  1  ,23  , 0 ,  0 ,  0 ,  0],
     [  0  , 5,   3  , 1  ,33 ,  1 ,  0 ,  1],
     [  0 ,  3 ,  1 ,  0  , 1,  23 ,  0 ,  0],
     [  2  , 0 ,  3  , 0 ,  2  , 0 , 17   ,0],
     [  0  , 4  , 3  , 0 ,  2,   0 ,  0 , 21]]


b= [ [ 15/22,   0,   4/22,   0,   1/22,   2/22,   0 ,  0],
     [  2/181, 168/181,   2/181,   1/181,   6/181  , 1/181  , 1/181 ,  0],
     [  1/52  , 8/52 , 39/52,   2/52,   1/52 ,  0 ,  0  , 1/52],
     [  0  ,10/34 ,  1/34,  23/34,   0 ,  0,   0 ,  0],
     [  0  , 5/44 ,  3/44,   1/44,  33/44  , 1/44 ,  0 ,  1/44],
     [  0 ,  3/28 ,  1/28 ,  0   ,1/28 , 23/28,   0,   0],
     [  2/24,   0 ,  3/24  , 0  , 2/24,   0,  17/24 ,  0],
     [  0  , 4/30 ,  3/30,   0 ,  2/30  , 0  , 0,  21/30]]


c = [[ 17  , 0  , 0 ,  1  , 1 ,  2 ,  1 ,  0],
     [  7 ,150  , 3 , 4  , 10 ,  4  , 3  , 0],
     [  0 ,  4  ,45  , 1  , 2  , 0   ,0   ,0],
     [  0  ,3 ,  1  ,29  , 0 ,  1 ,   0 ,  0],     
     [  0  , 4,   3  , 1  ,35 ,  1 ,  0 ,  0],    
     [  0 ,  2 ,  1 ,  0  , 0,  24 ,  0 ,  1],     
     [  1  , 1 ,  1  , 0 ,  1  , 0 , 20   ,0],     
     [  0  , 1  , 0  , 0 ,  2,   0 ,  1 , 26]]

d = [[ 17/22 ,  0/22  , 0 ,  1/22  , 1/22 ,  2/22 ,  1/22 ,  0],
     [  7/181, 150/181,   3/181,   4/181,   10/181  , 4/181  , 3/181 ,  0],
     [  0  , 4/52 , 45/52,   1/52,   2/52 ,  0 ,  0  , 0],   
     [  0  ,3/34 ,  1/34,  29/34,   0 ,  1/34,   0 ,  0],     
     [  0  , 4/44 ,  3/44,   1/44,  35/44  , 1/44 ,  0 ,  0],     
     [  0 ,  2/28 ,  1/28 ,  0   ,0 , 24/28,   0,   1/28],   
     [  1/24,   1/24 ,  1/24  , 0  , 1/24,   0,  20/24 ,  0], 
     [  0  , 1/30 ,  0,   0 ,  2/30  , 0  , 1/30,  26/30]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

group_counts = ["{0:0.0f}".format(value) for value in
                np.array(a).flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     np.array(b).flatten()]

labels = [f"{v1}\n{v2}" for v1, v2 in
          zip(group_counts,group_percentages)]

labels = np.asarray(labels).reshape(8,8)

categories = ['Adenosis', 'Ductal_Carcinoma', 'Fibroadenoma', 'Lobular_Carcinoma',
               'Mucinous_Carcinoma', 'Papillary_Carcinoma', 'Phyllodes_tumor', 'Tubular_adenoma']

plt.figure(figsize = (12,8))
plt.title('confusion Matrix x100 ohne Augmentation')
sns.heatmap(b, annot = labels, fmt='', xticklabels = categories, yticklabels = categories)
# Out:
# <AxesSubplot:title={'center':'confusion Matrix x100 ohne Augmentation'}>

# %%
group_counts = ["{0:0.0f}".format(value) for value in
                np.array(c).flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     np.array(d).flatten()]

labels = [f"{v1}\n{v2}" for v1, v2 in
          zip(group_counts,group_percentages)]

labels = np.asarray(labels).reshape(8,8)

categories = ['Adenosis', 'Ductal_Carcinoma', 'Fibroadenoma', 'Lobular_Carcinoma',
               'Mucinous_Carcinoma', 'Papillary_Carcinoma', 'Phyllodes_tumor', 'Tubular_adenoma']

plt.figure(figsize = (12,8))
plt.title('confusion Matrix x100 mit Data Augmentation')
sns.heatmap(d, annot = labels, fmt='', xticklabels = categories, yticklabels = categories)
# Out:
# <AxesSubplot:title={'center':'confusion Matrix x100 mit Data Augmentation'}>

# %%
def test_class_probabilities(model, device, test_loader, which_class):
    model.eval()
    actuals = []
    probabilities = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            prediction = output.argmax(dim=1, keepdim=True)
            actuals.extend(target.view_as(prediction) == which_class)
            probabilities.extend(np.exp(output[:, which_class]))
    return [i.item() for i in actuals], [i.item() for i in probabilities]

which_class = 1
actuals, class_probabilities = test_class_probabilities(net, device, testloader, which_class)

fpr, tpr, _ = sklearn.metrics.roc_curve(actuals, class_probabilities)
roc_auc = sklearn.metrics.auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC for label= %d ' % which_class)
plt.legend(loc="lower right")
plt.show()

# %%
print(valid_a)
# Out:
# [0.4354395605623722, 0.43612637370824814, 0.4464285717560695, 0.47218406601594043, 0.457417582663206, 0.47184065958628285, 0.5089285717560694, 0.5082417583236327, 0.5415521980478213, 0.5449862640637618, 0.5542582422494888, 0.5885989012626501, 0.6528159345571811, 0.6947115384615384, 0.773695055108804, 0.7877747256022233, 0.7857142858780347, 0.7654532967851713, 0.7881181320318809, 0.8310439563714541, 0.8169642858780347, 0.836195055108804, 0.8265796704934194, 0.8269230769230769, 0.8121565935703424, 0.821771978185727, 0.8100961538461539, 0.8265796704934194, 0.8193681320318809, 0.8265796704934194, 0.8238324179099157, 0.8293269230769231, 0.821771978185727, 0.8162774730187196, 0.8293269230769231, 0.8293269230769231, 0.8262362640637618, 0.8214285717560694, 0.8262362640637618, 0.8262362640637618, 0.8265796704934194, 0.7860576923076923, 0.8145604397241886, 0.8289835166472656, 0.8289835166472656, 0.8317307692307693, 0.8337912089549578, 0.828640110217608, 0.8269230769230769, 0.836195055108804, 0.8317307692307693, 0.8310439563714541, 0.8245192307692307, 0.8269230769230769, 0.8337912089549578, 0.8166208794483771, 0.8293269230769231, 0.8149038461538461, 0.821771978185727, 0.8190247256022233, 0.8262362640637618, 0.8258928576341042, 0.8241758243395731, 0.8262362640637618, 0.8262362640637618, 0.8289835166472656, 0.8238324179099157, 0.8173076923076923, 0.8145604397241886, 0.8313873628011117, 0.8221153846153846, 0.8173076923076923, 0.8337912089549578, 0.8221153846153846, 0.8289835166472656, 0.828640110217608, 0.8221153846153846, 0.8289835166472656, 0.8245192307692307, 0.836195055108804, 0.8241758243395731, 0.8097527474164963, 0.8193681320318809, 0.8221153846153846, 0.8241758243395731, 0.8238324179099157, 0.8245192307692307, 0.8241758243395731, 0.821771978185727, 0.8145604397241886, 0.8121565935703424, 0.8262362640637618, 0.8221153846153846, 0.8125, 0.821771978185727, 0.8100961538461539, 0.8046016486791464, 0.8173076923076923, 0.8169642858780347, 0.8169642858780347]
